# %%
import pandas as pd

# %%
df = pd.read_csv("/content/chipotle.tsv", sep='\t')

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# 1. Missing Values:Check for missing values in each column (Order ID, Quantity, Item Name, Choice Description, Item Price). How should missing values be handled?

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
mode_value = df['choice_description'].mode()[0]
df['choice_description'] = df['choice_description'].fillna(mode_value)

# %%
df['choice_description']
# Out:
# 0                                             [Diet Coke]
# 1                                            [Clementine]
# 2                                                 [Apple]
# 3                                             [Diet Coke]
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object

# %%
df.isnull().sum()
# Out:
# order_id              0
# quantity              0
# item_name             0
# choice_description    0
# item_price            0
# dtype: int64

# %% [markdown]
# 2. Data Types: Verify the data types of each column. Do they align with their expected types, and should any adjustments be made?

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df['item_price'] = df['item_price'].str.replace('$',' ')
df
# Out:
# <ipython-input-15-76b2c9bc9011>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['item_price'] = df['item_price'].str.replace('$',' ')
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# ...

# %%
df['item_price'] = pd.to_numeric(df['item_price'], errors = 'coerce', downcast = 'integer')
df.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %% [markdown]
# 3. Duplicated Entries:Identify and handle duplicated entries in the dataset. How might duplicates impact analysis, and what is the appropriate action?

# %%
duplicates = df[df.duplicated()]
df.duplicated().sum()
# Out:
# 59

# %%
df = df.drop_duplicates()
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                           [Diet Coke]        2.39
# ...

# %% [markdown]
# 4. Quantity and Item Price: Examine the Quantity and Item Price columns. Are there any inconsistencies or anomalies that need correction?

# %%
df['Item_price'] = df['item_price']
df[['quantity','Item_price']]
# Out:
#       quantity  Item_price
# 0            1        2.39
# 1            1        3.39
# 2            1        3.39
# 3            1        2.39
# 4            2       16.98
# ...        ...         ...
# 4617         1       11.75
# 4618         1       11.75
# 4619         1       11.25
# 4620         1        8.75
# 4621         1        8.75
#
# [4563 rows x 2 columns]

# %% [markdown]
# Question 5:Choice Description: Analyze the Choice Description column. How should choices be handled, especially when there are multiple descriptions for a single item?

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description', 'item_price',
#        'Item_price'],
#       dtype='object')

# %%
choices = df.groupby('item_name')['choice_description'].agg(lambda x: ', '.join(x)).reset_index()

# %%
df = pd.merge(df,choices, on='item_name', how='left', suffixes=('', '_aggregated'))

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4558      1833         1                          Steak Burrito
# 4559      1833         1                          Steak Burrito
# 4560      1834         1                     Chicken Salad Bowl
# 4561      1834         1                     Chicken Salad Bowl
# 4562      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                           [Diet Coke]        2.39
# ...

# %% [markdown]
# Question 6: Handling Special Characters: Check for special characters in text-based columns (e.g., Item Name, Choice Description). How can these be addressed for consistency?

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4558      1833         1                          Steak Burrito
# 4559      1833         1                          Steak Burrito
# 4560      1834         1                     Chicken Salad Bowl
# 4561      1834         1                     Chicken Salad Bowl
# 4562      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                           [Diet Coke]        2.39
# ...

# %%
df['choice_description'].replace('[^A-Za-z0-9\s]', inplace = True)
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4558      1833         1                          Steak Burrito
# 4559      1833         1                          Steak Burrito
# 4560      1834         1                     Chicken Salad Bowl
# 4561      1834         1                     Chicken Salad Bowl
# 4562      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                           [Diet Coke]        2.39
# ...

# %%
df.dtypes
# Out:
# order_id                           int64
# quantity                           int64
# item_name                         object
# choice_description                object
# item_price                       float64
# Item_price                       float64
# choice_description_aggregated     object
# dtype: object

# %% [markdown]
# Question 7:Order Id Integrity: Cross-reference the Order ID column for integrity. Are there any irregularities or patterns that need validation?

# %%
astype = df['order_id'].astype(str)
astype
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          2
#         ...
# 4558    1833
# 4559    1833
# 4560    1834
# 4561    1834
# 4562    1834
# Name: order_id, Length: 4563, dtype: object

# %%
missing_values = df['order_id'].isnull().sum()
missing_values
# Out:
# 0

# %%
duplicate_values = df['order_id'].duplicated().sum()
duplicate_values
# Out:
# 2729

# %%
cross_reference = df.groupby('order_id').nunique()
cross_reference
# Out:
#           quantity  item_name  choice_description  item_price  Item_price  \
# order_id
# 1                1          4                   3           2           2
# 2                1          1                   1           1           1
# 3                1          2                   2           2           2
# 4                1          2                   2           2           2
# 5                1          2                   2           2           2
# ...            ...        ...                 ...         ...         ...
# 1830             1          2                   2           2           2
# 1831             1          3                   2           3           3
# 1832             1          2                   2           2           2
# 1833             1          1                   2           1           1
# 1834             1          1                   3           2           2
#
#           choice_description_aggregated
# order_id
# ...

# %%
unique_values = df['order_id'].nunique()
unique_values
# Out:
# 1834

# %% [markdown]
# Question 8:Standardize the Item Name column. Are there variations that can be unified for better analysis?

# %%
df['item_name'] = df['item_name'].str.lower()  # or use str.upper() for uppercase

# %%
df['item_name'] = df['item_name'].str.strip()

# %%
df['item_name'] = df['item_name'].str.replace('[^A-Za-z0-9\s]', '_', regex=True)

# %%
name_mapping = {'cola': 'cola', 'coke': 'cola', 'pepsi': 'cola', 'fizzy drink': 'cola'}
df['Item_Name'] = df['item_name'].replace(name_mapping)

# %%
df['Item_Name'] = df['Item_Name'].replace({'Ltd.': 'Limited', 'Corp': 'Corporation'}, regex=True)

# %%
df['Item_Type'] = df['Item_Name'].replace({'Burger': 'Fast Food', 'Pizza': 'Fast Food', 'Salad': 'Healthy'})

# %%
df['Item_Type']
# Out:
# 0                chips and fresh tomato salsa
# 1                                        izze
# 2                            nantucket nectar
# 3       chips and tomatillo_green chili salsa
# 4                                chicken bowl
#                         ...
# 4558                            steak burrito
# 4559                            steak burrito
# 4560                       chicken salad bowl
# 4561                       chicken salad bowl
# 4562                       chicken salad bowl
# Name: Item_Type, Length: 4563, dtype: object

# %% [markdown]
# Question 9: Quantity and Price Relationships: Investigate the relationships between Quantity and Item Price. Are there cases where adjustments need to be made for accurate analysis?

# %%
type(df.item_price)
# Out:
# pandas.core.series.Series

# %%
df.item_price.dtype
# Out:
# dtype('float64')

# %%
df['Item_price'] = df['item_price'].astype(float)

# %%
df.Item_price.sum()
# Out:
# 34177.25

# %%
df[['quantity','Item_price']]
# Out:
#       quantity  Item_price
# 0            1        2.39
# 1            1        3.39
# 2            1        3.39
# 3            1        2.39
# 4            2       16.98
# ...        ...         ...
# 4558         1       11.75
# 4559         1       11.75
# 4560         1       11.25
# 4561         1        8.75
# 4562         1        8.75
#
# [4563 rows x 2 columns]

# %% [markdown]
# Question 10:Data Integrity Check: Perform a data integrity check by ensuring that quantities and prices align with the corresponding items and descriptions.

# %%
cross_references = df.groupby(['item_name', 'choice_description'])[['quantity', 'item_price']].sum()
cross_references
# Out:
#                                                                       quantity  \
# item_name         choice_description
# 6 pack soft drink [Coke]                                                    21
#                   [Diet Coke]                                               25
#                   [Lemonade]                                                 2
#                   [Nestea]                                                   2
#                   [Sprite]                                                   5
# ...                                                                        ...
# veggie soft tacos [Fresh Tomato Salsa, [Black Beans, Cheese, Sour...         1
#                   [Fresh Tomato Salsa, [Fajita Vegetables, Rice, ...         1
#                   [Roasted Chili Corn Salsa (Medium), [Black Bean...         1
#                   [Roasted Chili Corn Salsa, [Fajita Vegetables, ...         1
# ...

# %% [markdown]
# Question 11:Converting to CSV:If needed, convert the cleaned dataset to a CSV file using the to_csv function with sep=','.

# %%
csv_file = 'org_dataset.csv'

# %%
df.to_csv(csv_file, sep=',', index=False)

# %%
print(f"Cleaned dataset has been saved to: {csv_file}")
# Out:
# Cleaned dataset has been saved to: org_dataset.csv

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           chips and fresh tomato salsa
# 1            1         1                                   izze
# 2            1         1                       nantucket nectar
# 3            1         1  chips and tomatillo_green chili salsa
# 4            2         2                           chicken bowl
# ...        ...       ...                                    ...
# 4558      1833         1                          steak burrito
# 4559      1833         1                          steak burrito
# 4560      1834         1                     chicken salad bowl
# 4561      1834         1                     chicken salad bowl
# 4562      1834         1                     chicken salad bowl
#
#                                      choice_description  item_price  \
# 0                                           [Diet Coke]        2.39
# ...

# %% [markdown]
# Question 12:Handling Categorical Data:For categorical columns (e.g., Item Name), consider encoding or transforming them into a format suitable for analysis

# %%
data = {'item_name': ['Chips and Fresh Tomato Salsa', 'lzze', 'Nantucket Nectar', 'Chips and Tomatillo-Green Chili salsa', 'Chicken bowl', 'Steak Burrito', 'Chicken Salad Bowl']}
df = pd.DataFrame(data)

# %%
one_hot = pd.get_dummies(df, columns=['item_name'], prefix='Item')

# %%
label = df.copy()
for column in label.columns:
    label['item_name'] = label['item_name'].astype('category').cat.codes

# %%
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#                                item_name
# 0           Chips and Fresh Tomato Salsa
# 1                                   lzze
# 2                       Nantucket Nectar
# 3  Chips and Tomatillo-Green Chili salsa
# 4                           Chicken bowl
# 5                          Steak Burrito
# 6                     Chicken Salad Bowl

# %%
print("\nLabel Encoded DataFrame:")
print(label)
# Out:
# Label Encoded DataFrame:
#    item_name
# 0          2
# 1          6
# 2          4
# 3          3
# 4          1
# 5          5
# 6          0

# %% [markdown]
# Question 13:Consistent Quantity and Price Units:Ensure consistency in units for Quantity and Item Price. Should any conversions or adjustments be made for uniform analysis?

# %%
data = {'quantity': [1, 1, 1, 1, 2, 1, 1, 1, 1, 1],
        'item_price (USD)': [2.39, 3.39, 3.39, 2.39, 16.98, 11.75, 11.75, 11.25, 8.75, 8.75]}
df = pd.DataFrame(data)

# %%
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#    quantity  item_price (USD)
# 0         1              2.39
# 1         1              3.39
# 2         1              3.39
# 3         1              2.39
# 4         2             16.98
# 5         1             11.75
# 6         1             11.75
# 7         1             11.25
# 8         1              8.75
# 9         1              8.75

# %%
unique_quantity_units = df['quantity'].unique()
print("\nUnique Quantity Units:")
print(unique_quantity_units)
# Out:
# Unique Quantity Units:
# [1 2]

# %%
unique_price_units = df['item_price (USD)'].unique()
print("\nUnique Item Price Units:")
print(unique_price_units)
# Out:
# Unique Item Price Units:
# [ 2.39  3.39 16.98 11.75 11.25  8.75]

# %%
print("\nDataFrame after Conversions or Adjustments:")
print(df)
# Out:
# DataFrame after Conversions or Adjustments:
#    quantity  item_price (USD)
# 0         1              2.39
# 1         1              3.39
# 2         1              3.39
# 3         1              2.39
# 4         2             16.98
# 5         1             11.75
# 6         1             11.75
# 7         1             11.25
# 8         1              8.75
# 9         1              8.75
